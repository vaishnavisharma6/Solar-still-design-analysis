# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavisharma6/Solar-still-design-analysis/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import tensorflow as tf
from tensorflow import keras
from sklearn.utils import shuffle
import numpy as np
from IPython.display import clear_output
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import pandas as pd
import io

# %%
url = 'https://github.com/vaishnavisharma6/Solar-still-design-analysis/raw/main/DATA.csv'
df = pd.read_csv(url)
data = shuffle(df)
print(data)
# Out:
#      Evaporative Water temperature\n(0C )  Glass cover temperature (0C)  \
# 20                                27.1287                       23.1265
# 85                                32.1205                       28.6512
# 34                                43.2906                       39.6017
# 19                                35.7280                       32.0236
# 74                                33.6512                       29.4512
# ..                                    ...                           ...
# 87                                25.0000                       21.3022
# 0                                 20.0000                       16.2476
# 18                                49.3921                       45.6725
# 60                                65.0158                       65.9536
# 106                               32.8408                       29.1686
#
#      Ambient temperature (0C)  Solar intensity (kw/ m2)  \
# 20                       31.0                  262.8890
# 85                       32.5                  319.6175
# 34                       35.0                  547.9301
# 19                       31.5                  452.2100
# 74                       33.0                  313.1555
# ..                        ...                       ...
# 87                       29.0                  155.2078
# 0                        15.0                   64.0365
# 18                       32.0                  625.1571
# 60                       42.0                  822.9057
# 106                      39.0                  415.6669
#
#      Productivity (ml/m 2hr)
# 20                  73.14530
# 85                  87.12340
# 34                 168.75130
# 19                 118.33550
# 74                  88.12478
# ..                       ...
# 87                  68.75920
# 0                   54.05330
# 18                 225.19210
# 60                 438.93460
# 106                101.76750
#
# [131 rows x 5 columns]

# %%
N = data.shape[0]
Ntrain = 92
Nvalid = 20
Ntest = N - Ntrain - Nvalid

# %%
data = data.to_numpy()
Xtrain = data[0:Ntrain, 0:4]
Ytrain = data[0:Ntrain, 4]
Xvalid = data[Ntrain: Ntrain+Nvalid, 0:4]
Yvalid = data[Ntrain: Ntrain+Nvalid, 4]
Xtest = data[Ntrain+Nvalid:-1, 0:4]
Ytest = data[Ntrain+Nvalid: -1, 4]

# %%
class Trainingplot(tf.keras.callbacks.Callback):
  def on_train_begin(self, logs = {}):
    self.losses = []
    self.val_losses = []
    self.logs = []
  def on_epoch_end(self, epoch, logs = {}):
    self.logs.append(logs)
    self.losses.append(logs.get('loss'))
    self.val_losses.append(logs.get('val_loss'))  

    if epoch >1 and epoch%500 == 0:                                                             #callback function
       clear_output(wait = True)
       N = np.arange(0, len(self.losses))  

       plt.figure()
       plt.semilogy(N, self.losses, label = 'Train_loss')
       plt.semilogy(N, self.val_losses, label = 'Validation loss')
       plt.title('After epoch = {}'.format(epoch))
       plt.xlabel('Epoch #')
       plt.ylabel('Loss')
       plt.legend()
       plt.show()

# %%
model = Sequential()
model.add(Dense(512, input_shape = (4,), activation = 'relu'))
model.add(Dense(128, activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(32, activation = 'relu'))
model.add(Dense(1))

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['mse'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 512)               2560
#
#  dense_15 (Dense)            (None, 128)               65664
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  dense_17 (Dense)            (None, 32)                2080
#
#  dense_18 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 78,593
# Trainable params: 78,593
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_losses = Trainingplot()
model.fit(Xtrain, Ytrain, epochs = 30000, verbose = 0, batch_size = 32, shuffle = True, validation_data = (Xvalid, Yvalid), callbacks = [plot_losses])

# %%
train_loss, train_mse = model.evaluate(Xtrain, Ytrain)
print('Train accuracy:', train_mse)
valid_loss, valid_mse = model.evaluate(Xvalid, Yvalid)
print('Validation accuracy:', valid_mse)
test_loss, test_mse = model.evaluate(Xtest, Ytest)
print('Test error:', test_mse)

plt.figure(figsize=(8,8))
plt.subplot(3,1,1)
plt.plot(Xtrain[:,3],Ytrain,'o',color='red',label='True')
plt.plot(Xtrain[:,3],model.predict(Xtrain),'x',color='blue',label='Prediction')
plt.title('Training data')
plt.legend()

plt.subplot(3,1,2)
plt.plot(Xvalid[:,3],Yvalid,'o',color='red',label='True')
plt.plot(Xvalid[:,3],model.predict(Xvalid),'x',color='blue',label='Prediction')
plt.title('Validation data')
plt.legend()

plt.subplot(3,1,3)
plt.plot(Xtest[:,3],Ytest,'o',color='red',label='True')
plt.plot(Xtest[:,3],model.predict(Xtest),'x',color='blue',label='Prediction')
plt.title('Testing data')
plt.legend()

plt.show()
# Out:
# 3/3 [==============================] - 0s 8ms/step - loss: 1.8280 - mse: 1.8280
# Train accuracy: 1.8280308246612549
# 1/1 [==============================] - 0s 36ms/step - loss: 9.9097 - mse: 9.9097
# Validation accuracy: 9.909673690795898
# 1/1 [==============================] - 0s 63ms/step - loss: 912.2348 - mse: 912.2348
# Test error: 912.2348022460938
# 3/3 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
